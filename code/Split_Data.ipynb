# %% [markdown]
# # 1 Split Data

# %%
import json

# %%
with open('../data/business_city_Chinese.json', 'r') as file:
    for line in file:
        parsed = json.loads(line)
        business_id = parsed['business_id']
        fileName = business_id + '.json'
        with open('../data/ChineseBusiness/' + fileName, 'w') as file2:
            file2.write(json.dumps(parsed, indent = 4))

# %% [markdown]
# ## Generate List for Dropdown Menu

# %%
all_business = []
with open('../data/business_city_Chinese.json', 'r') as file:
    for line in file:
        parsed = json.loads(line)
        all_business.append({
            'name': parsed['name'],
            'business_id': parsed['business_id']
        })

# %%
all_business = sorted(all_business, key = lambda x:  x['name'])

all_business_string = json.dumps(all_business, indent = 4)
print(all_business_string)
# Out:
# [
#     {
#         "name": "70 Chinese and Sushi",
#         "business_id": "bmcZnH1UAAB2iO_R2PFrnw"
#     },
#     {
#         "name": "A Panda Buffet",
#         "business_id": "1qw65j15MqKqYkljH_iSyA"
#     },
#     {
#         "name": "A Sakura",
#         "business_id": "Q6_YIK0yUI8HEgqrOIE-1Q"
#     },
#     {
#         "name": "A-Wok Restaurant",
#         "business_id": "fZfoi-VMMcv9Uc4QYgbOHw"
#     },
#     {
#         "name": "A8 China",
#         "business_id": "7OKQ4ENVfPfxtDqFOG7x0g"
#     },
#     {
#         "name": "Amazing Wok",
#         "business_id": "fjE-jiwnTQysz-rLl6YMQg"
#     },
#     {
#         "name": "Amazing Wok II",
#         "business_id": "cxq_iu2Zl5jm6qLGfff5eA"
#     },
#     {
#         "name": "AnSun",
#         "business_id": "exx_UjNFHW2uPI1ZT7JFNA"
#     },
#     {
#         "name": "Aristo Bistro",
#         "business_id": "0I0yATfnNQJB-A-IPGgqDA"
#     },
#     {
#         "name": "Aseoma",
#         "business_id": "TpLbrBsHSej6Snb6LXDYxg"
# ...

# %% [markdown]
# ##  Ratings for Histogram

# %%
all_ratings = []
with open('../data/business_city_Chinese.json', 'r') as file:
    for line in file:
        parsed = json.loads(line)
        all_ratings.append(parsed['stars'])

# %%
from collections import Counter
ratings = dict(Counter(all_ratings))
print(json.dumps(ratings, indent = 4))
# Out:
# {
#     "2.5": 91,
#     "3.5": 206,
#     "4.0": 164,
#     "3.0": 192,
#     "2.0": 31,
#     "1.5": 8,
#     "4.5": 48,
#     "5.0": 7,
#     "1.0": 4
# }

# %%
sum(all_ratings) / len(all_ratings)
# Out:
# 3.341544607190413

# %% [markdown]
# ## Number of reviews

# %%
all_reviews = []
with open('../data/business_city_Chinese.json', 'r') as file:
    for line in file:
        parsed = json.loads(line)
        all_reviews.append(parsed['review_count'])

# %%
sum(all_reviews) / len(all_reviews)
# Out:
# 43.33821571238349

# %% [markdown]
# ## Opening Time

# %% [markdown]
# ### Monday

# %%
s = []
d = []
with open('../data/business_city_Chinese.json', 'r') as file:
    for line in file:
        parsed = json.loads(line)
        if parsed['stars'] >=4 and parsed['hours'] is not None and 'Monday' in parsed['hours']:
            time0 = parsed['hours']['Monday'].split('-')
#             print(time0[0].split)
            start_hour = int(time0[0].split(':')[0])
            start_minute = int(time0[0].split(':')[1])/60
            end_hour = int(time0[1].split(':')[0])
            end_minute = int(time0[1].split(':')[1])/60
            if start_hour != 0:
                start = start_hour + start_minute
                duration = end_hour - start_hour + end_minute - start_minute
                s.append(start)
                d.append(duration)
#         all_reviews.append(parsed['review_count'])

print(sum(s) / len(s))
print(sum(d) / len(d))
# Out:
# 11.492537313432836
# 9.847014925373134

# %% [markdown]
# ### Tuesday

# %%
s = []
d = []
with open('../data/business_city_Chinese.json', 'r') as file:
    for line in file:
        parsed = json.loads(line)
        if parsed['stars'] >=4 and parsed['hours'] is not None and 'Tuesday' in parsed['hours']:
            time0 = parsed['hours']['Tuesday'].split('-')
#             print(time0[0].split)
            start_hour = int(time0[0].split(':')[0])
            start_minute = int(time0[0].split(':')[1])/60
            end_hour = int(time0[1].split(':')[0])
            end_minute = int(time0[1].split(':')[1])/60
            if start_hour != 0:
                start = start_hour + start_minute
                duration = end_hour - start_hour + end_minute - start_minute
                s.append(start)
                d.append(duration)
#         all_reviews.append(parsed['review_count'])

print(sum(s) / len(s))
print(sum(d) / len(d))
# Out:
# 11.429276315789474
# 9.794407894736842

# %%
s = []
d = []
with open('../data/business_city_Chinese.json', 'r') as file:
    for line in file:
        parsed = json.loads(line)
        if parsed['stars'] >=4 and parsed['hours'] is not None and 'Wednesday' in parsed['hours']:
            time0 = parsed['hours']['Wednesday'].split('-')
#             print(time0[0].split)
            start_hour = int(time0[0].split(':')[0])
            start_minute = int(time0[0].split(':')[1])/60
            end_hour = int(time0[1].split(':')[0])
            end_minute = int(time0[1].split(':')[1])/60
            if start_hour != 0:
                start = start_hour + start_minute
                duration = end_hour - start_hour + end_minute - start_minute
                s.append(start)
                d.append(duration)
#         all_reviews.append(parsed['review_count'])

print(sum(s) / len(s))
print(sum(d) / len(d))
# Out:
# 11.394171779141104
# 9.817484662576687

# %%
s = []
d = []
with open('../data/business_city_Chinese.json', 'r') as file:
    for line in file:
        parsed = json.loads(line)
        if parsed['stars'] >=4 and parsed['hours'] is not None and 'Thursday' in parsed['hours']:
            time0 = parsed['hours']['Thursday'].split('-')
#             print(time0[0].split)
            start_hour = int(time0[0].split(':')[0])
            start_minute = int(time0[0].split(':')[1])/60
            end_hour = int(time0[1].split(':')[0])
            end_minute = int(time0[1].split(':')[1])/60
            if start_hour != 0:
                start = start_hour + start_minute
                duration = end_hour - start_hour + end_minute - start_minute
                s.append(start)
                d.append(duration)
#         all_reviews.append(parsed['review_count'])

print(sum(s) / len(s))
print(sum(d) / len(d))
# Out:
# 11.498475609756097
# 9.794207317073171

# %%
s = []
d = []
with open('../data/business_city_Chinese.json', 'r') as file:
    for line in file:
        parsed = json.loads(line)
        if parsed['stars'] >=4 and parsed['hours'] is not None and 'Friday' in parsed['hours']:
            time0 = parsed['hours']['Friday'].split('-')
#             print(time0[0].split)
            start_hour = int(time0[0].split(':')[0])
            start_minute = int(time0[0].split(':')[1])/60
            end_hour = int(time0[1].split(':')[0])
            end_minute = int(time0[1].split(':')[1])/60
            if start_hour != 0:
                start = start_hour + start_minute
                duration = end_hour - start_hour + end_minute - start_minute
                s.append(start)
                d.append(duration)
#         all_reviews.append(parsed['review_count'])

print(sum(s) / len(s))
print(sum(d) / len(d))
# Out:
# 11.458841463414634
# 10.278963414634147

# %%
s = []
d = []
with open('../data/business_city_Chinese.json', 'r') as file:
    for line in file:
        parsed = json.loads(line)
        if parsed['stars'] >=4 and parsed['hours'] is not None and 'Saturday' in parsed['hours']:
            time0 = parsed['hours']['Saturday'].split('-')
#             print(time0[0].split)
            start_hour = int(time0[0].split(':')[0])
            start_minute = int(time0[0].split(':')[1])/60
            end_hour = int(time0[1].split(':')[0])
            end_minute = int(time0[1].split(':')[1])/60
            if start_hour != 0:
                start = start_hour + start_minute
                duration = end_hour - start_hour + end_minute - start_minute
                s.append(start)
                d.append(duration)
#         all_reviews.append(parsed['review_count'])

print(sum(s) / len(s))
print(sum(d) / len(d))
# Out:
# 11.6296875
# 10.2390625

# %%
s = []
d = []
with open('../data/business_city_Chinese.json', 'r') as file:
    for line in file:
        parsed = json.loads(line)
        if parsed['stars'] >=4 and parsed['hours'] is not None and 'Sunday' in parsed['hours']:
            time0 = parsed['hours']['Sunday'].split('-')
#             print(time0[0].split)
            start_hour = int(time0[0].split(':')[0])
            start_minute = int(time0[0].split(':')[1])/60
            end_hour = int(time0[1].split(':')[0])
            end_minute = int(time0[1].split(':')[1])/60
            if start_hour != 0:
                start = start_hour + start_minute
                duration = end_hour - start_hour + end_minute - start_minute
                s.append(start)
                d.append(duration)
#         all_reviews.append(parsed['review_count'])

print(sum(s) / len(s))
print(sum(d) / len(d))
# Out:
# 12.23993288590604
# 8.911073825503356

# %% [markdown]
# ## Generate new data with parsed opening time

# %%
with open('../data/business_city_Chinese.json', 'r') as file:
    for line in file:
        parsed = json.loads(line)
        business_id = parsed['business_id']
        startTime = []
        durationLength = []
        for day in ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']:
            if 'hours' not in parsed or parsed['hours'] is None or day not in parsed['hours']:
                startTime.append(0)
                durationLength.append(0)
            else:
                time0 = parsed['hours'][day].split('-')
                start_hour = int(time0[0].split(':')[0])
                start_minute = int(time0[0].split(':')[1])/60
                end_hour = int(time0[1].split(':')[0])
                end_minute = int(time0[1].split(':')[1])/60
                start = start_hour + start_minute
                duration = end_hour - start_hour + end_minute - start_minute
                if duration > 0:
                    startTime.append(start)
                    durationLength.append(duration)
                else:
                    startTime.append(0)
                    durationLength.append(0)
        parsed['parsedHours'] = {
            'startTime': startTime,
            'durationLength': durationLength
        }
        fileName = business_id + '.json'
        with open('../data/ChineseBusiness/' + fileName, 'w') as file2:
            file2.write(json.dumps(parsed, indent = 4))
        print(parsed['parsedHours'])
# Out:
# {'startTime': [10.5, 10.5, 10.5, 10.5, 10.5, 10.5, 10.5], 'durationLength': [11.0, 11.0, 11.0, 11.0, 11.0, 11.0, 11.0]}
# {'startTime': [0, 0, 0, 0, 0, 0, 0], 'durationLength': [0, 0, 0, 0, 0, 0, 0]}
# {'startTime': [11.0, 11.0, 11.0, 11.0, 11.0, 11.0, 15.0], 'durationLength': [10.5, 10.5, 10.5, 10.5, 11.0, 11.0, 6.0]}
# {'startTime': [0, 0, 0, 0, 0, 0, 0], 'durationLength': [0, 0, 0, 0, 0, 0, 0]}
# {'startTime': [11.0, 11.0, 11.0, 11.0, 11.0, 11.0, 11.0], 'durationLength': [11.0, 11.0, 11.0, 11.0, 11.5, 11.5, 11.0]}
# {'startTime': [0, 0, 0, 0, 0, 0, 0], 'durationLength': [0, 0, 0, 0, 0, 0, 0]}
# {'startTime': [17.0, 11.0, 11.0, 11.0, 11.0, 12.0, 16.0], 'durationLength': [4.0, 10.5, 10.5, 10.5, 12.0, 11.0, 5.0]}
# {'startTime': [0, 0, 0, 0, 0, 0, 0], 'durationLength': [0, 0, 0, 0, 0, 0, 0]}
# {'startTime': [11.0, 11.0, 11.0, 11.0, 11.0, 11.0, 12.0], 'durationLength': [11.5, 11.5, 11.5, 11.5, 12.0, 12.0, 10.0]}
# ...
